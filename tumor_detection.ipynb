# %%
#We want to create a deep learning model that can detect whether a brain MRI scan shows a tumor or not.
#Input:

#An image of a brain MRI scan.
#✅ Output:

    #Yes (1) – Tumor detected

    #No (0) – No tumor detected
 ##Goal:

#Build a model that can look at MRI images and accurately say whether a tumor is present — with at least 90% accuracy.

# %%
pip install scipy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install h5py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

# Set path to .mat folder
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_1-766"

# List all .mat files
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]
print("Total .mat files:", len(files))

# Load one .mat file using h5py
file_path = os.path.join(mat_dir, files[0])
print("Opening file:", file_path)

with h5py.File(file_path, 'r') as f:
    # Print available top-level keys
    print("Top-level keys:", list(f.keys()))

    # Explore the structure
    cjdata = f['cjdata']

    print("Sub-keys in cjdata:", list(cjdata.keys()))

    # Access the image
    image = np.array(cjdata['image'])        # Load image data
    label = np.array(cjdata['label'])        # Load label

    print("Image shape:", image.shape)
    print("Label:", label[0][0])  # Extract scalar label value

    # Show the image
    plt.imshow(image, cmap='gray')
    plt.title(f"Label: {label[0][0]}")
    plt.axis("off")
    plt.show()
# Out:
# Total .mat files: 766
# Opening file: C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_1-766\1.mat
# Top-level keys: ['cjdata']
# Sub-keys in cjdata: ['PID', 'image', 'label', 'tumorBorder', 'tumorMask']
# Image shape: (512, 512)
# Label: 1.0

# %%
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

# Set path to .mat folder
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_767-1532"

# List all .mat files
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]
print("Total .mat files:", len(files))

# Load one .mat file using h5py
file_path = os.path.join(mat_dir, files[0])
print("Opening file:", file_path)

with h5py.File(file_path, 'r') as f:
    # Print available top-level keys
    print("Top-level keys:", list(f.keys()))

    # Explore the structure
    cjdata = f['cjdata']

    print("Sub-keys in cjdata:", list(cjdata.keys()))

    # Access the image
    image = np.array(cjdata['image'])        # Load image data
    label = np.array(cjdata['label'])        # Load label

    print("Image shape:", image.shape)
    print("Label:", label[0][0])  # Extract scalar label value

    # Show the image
    plt.imshow(image, cmap='gray')
    plt.title(f"Label: {label[0][0]}")
    plt.axis("off")
    plt.show()
# Out:
# Total .mat files: 766
# Opening file: C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_767-1532\1000.mat
# Top-level keys: ['cjdata']
# Sub-keys in cjdata: ['PID', 'image', 'label', 'tumorBorder', 'tumorMask']
# Image shape: (512, 512)
# Label: 3.0

# %%
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

# Set path to .mat folder
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_1533-2298"

# List all .mat files
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]
print("Total .mat files:", len(files))

# Load one .mat file using h5py
file_path = os.path.join(mat_dir, files[0])
print("Opening file:", file_path)

with h5py.File(file_path, 'r') as f:
    # Print available top-level keys
    print("Top-level keys:", list(f.keys()))

    # Explore the structure
    cjdata = f['cjdata']

    print("Sub-keys in cjdata:", list(cjdata.keys()))

    # Access the image
    image = np.array(cjdata['image'])        # Load image data
    label = np.array(cjdata['label'])        # Load label

    print("Image shape:", image.shape)
    print("Label:", label[0][0])  # Extract scalar label value

    # Show the image
    plt.imshow(image, cmap='gray')
    plt.title(f"Label: {label[0][0]}")
    plt.axis("off")
    plt.show()
# Out:
# Total .mat files: 766
# Opening file: C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_1533-2298\1533.mat
# Top-level keys: ['cjdata']
# Sub-keys in cjdata: ['PID', 'image', 'label', 'tumorBorder', 'tumorMask']
# Image shape: (512, 512)
# Label: 3.0

# %%
import os
import h5py
import numpy as np
import matplotlib.pyplot as plt

# Set path to .mat folder
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_2299-3064"

# List all .mat files
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]
print("Total .mat files:", len(files))

# Load one .mat file using h5py
file_path = os.path.join(mat_dir, files[0])
print("Opening file:", file_path)

with h5py.File(file_path, 'r') as f:
    # Print available top-level keys
    print("Top-level keys:", list(f.keys()))

    # Explore the structure
    cjdata = f['cjdata']

    print("Sub-keys in cjdata:", list(cjdata.keys()))

    # Access the image
    image = np.array(cjdata['image'])        # Load image data
    label = np.array(cjdata['label'])        # Load label

    print("Image shape:", image.shape)
    print("Label:", label[0][0])  # Extract scalar label value

    # Show the image
    plt.imshow(image, cmap='gray')
    plt.title(f"Label: {label[0][0]}")
    plt.axis("off")
    plt.show()
# Out:
# Total .mat files: 766
# Opening file: C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_2299-3064\2299.mat
# Top-level keys: ['cjdata']
# Sub-keys in cjdata: ['PID', 'image', 'label', 'tumorBorder', 'tumorMask']
# Image shape: (512, 512)
# Label: 2.0

# %%
import os
import h5py
import cv2
import numpy as np
from tqdm import tqdm
import zipfile

# Input .mat files directory
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_1-766"

# Output image folder (Kaggle-style)
output_folder = "converted_dataset"

# Make sure the output folders exist
os.makedirs(output_folder, exist_ok=True)
tumor_types = {1: "meningioma", 2: "glioma", 3: "pituitary"}
for folder in tumor_types.values():
    os.makedirs(os.path.join(output_folder, folder), exist_ok=True)

# Resize size
IMG_SIZE = 224

# Process each .mat file
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]

for idx, file_name in enumerate(tqdm(files)):
    try:
        file_path = os.path.join(mat_dir, file_name)
        with h5py.File(file_path, 'r') as f:
            cjdata = f['cjdata']
            image = np.array(cjdata['image'])
            label = int(np.array(cjdata['label'])[0][0])

            if label not in tumor_types:
                continue  # Skip unknown labels

            # Resize and normalize image
            image_resized = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
            image_resized = np.uint8(image_resized / np.max(image_resized) * 255)

            # Output path
            save_path = os.path.join(output_folder, tumor_types[label], f"{idx}.jpg")

            # Save the image
            cv2.imwrite(save_path, image_resized)

    except Exception as e:
        print(f"❌ Error in file {file_name}: {e}")

print("✅ All images converted and saved!")

# 📦 ZIP the entire folder into Kaggle-style format
zip_filename = "kaggle_format.zip"
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(output_folder):
        for file in files:
            full_path = os.path.join(root, file)
            arcname = os.path.relpath(full_path, output_folder)
            zipf.write(full_path, arcname)

print(f"✅ Zipping complete! Output saved as: {zip_filename}")
# Out:
# 100%|██████████| 766/766 [00:04<00:00, 161.55it/s]
# ✅ All images converted and saved!
# ✅ Zipping complete! Output saved as: kaggle_format.zip

# %%
pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script tqdm.exe is installed in 'C:\Users\m6793\AppData\Roaming\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import os
import h5py
import cv2
import numpy as np
from tqdm import tqdm
import zipfile

# Input .mat files directory
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_767-1532"

# Output image folder (Kaggle-style)
output_folder = "converted_dataset"

# Make sure the output folders exist
os.makedirs(output_folder, exist_ok=True)
tumor_types = {1: "meningioma", 2: "glioma", 3: "pituitary"}
for folder in tumor_types.values():
    os.makedirs(os.path.join(output_folder, folder), exist_ok=True)

# Resize size
IMG_SIZE = 224

# Process each .mat file
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]

for idx, file_name in enumerate(tqdm(files)):
    try:
        file_path = os.path.join(mat_dir, file_name)
        with h5py.File(file_path, 'r') as f:
            cjdata = f['cjdata']
            image = np.array(cjdata['image'])
            label = int(np.array(cjdata['label'])[0][0])

            if label not in tumor_types:
                continue  # Skip unknown labels

            # Resize and normalize image
            image_resized = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
            image_resized = np.uint8(image_resized / np.max(image_resized) * 255)

            # Output path
            save_path = os.path.join(output_folder, tumor_types[label], f"{idx}.jpg")

            # Save the image
            cv2.imwrite(save_path, image_resized)

    except Exception as e:
        print(f"❌ Error in file {file_name}: {e}")

print("✅ All images converted and saved!")

# 📦 ZIP the entire folder into Kaggle-style format
zip_filename = "kaggle_format.zip"
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(output_folder):
        for file in files:
            full_path = os.path.join(root, file)
            arcname = os.path.relpath(full_path, output_folder)
            zipf.write(full_path, arcname)

print(f"✅ Zipping complete! Output saved as: {zip_filename}")
# Out:
# 100%|██████████| 766/766 [00:15<00:00, 49.51it/s]
# ✅ All images converted and saved!
# ✅ Zipping complete! Output saved as: kaggle_format.zip

# %%
import os
import h5py
import cv2
import numpy as np
from tqdm import tqdm
import zipfile

# Input .mat files directory
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_1533-2298"

# Output image folder (Kaggle-style)
output_folder = "converted_dataset"

# Make sure the output folders exist
os.makedirs(output_folder, exist_ok=True)
tumor_types = {1: "meningioma", 2: "glioma", 3: "pituitary"}
for folder in tumor_types.values():
    os.makedirs(os.path.join(output_folder, folder), exist_ok=True)

# Resize size
IMG_SIZE = 224

# Process each .mat file
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]

for idx, file_name in enumerate(tqdm(files)):
    try:
        file_path = os.path.join(mat_dir, file_name)
        with h5py.File(file_path, 'r') as f:
            cjdata = f['cjdata']
            image = np.array(cjdata['image'])
            label = int(np.array(cjdata['label'])[0][0])

            if label not in tumor_types:
                continue  # Skip unknown labels

            # Resize and normalize image
            image_resized = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
            image_resized = np.uint8(image_resized / np.max(image_resized) * 255)

            # Output path
            save_path = os.path.join(output_folder, tumor_types[label], f"{idx}.jpg")

            # Save the image
            cv2.imwrite(save_path, image_resized)

    except Exception as e:
        print(f"❌ Error in file {file_name}: {e}")

print("✅ All images converted and saved!")

# 📦 ZIP the entire folder into Kaggle-style format
zip_filename = "kaggle_format.zip"
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(output_folder):
        for file in files:
            full_path = os.path.join(root, file)
            arcname = os.path.relpath(full_path, output_folder)
            zipf.write(full_path, arcname)

print(f"✅ Zipping complete! Output saved as: {zip_filename}")
# Out:
# 100%|██████████| 766/766 [00:17<00:00, 42.91it/s]
# ✅ All images converted and saved!
# ✅ Zipping complete! Output saved as: kaggle_format.zip

# %%
import os
import h5py
import cv2
import numpy as np
from tqdm import tqdm
import zipfile

# Input .mat files directory
mat_dir = r"C:\Users\m6793\Downloads\1512427\brainTumorDataPublic_2299-3064"

# Output image folder (Kaggle-style)
output_folder = "converted_dataset"

# Make sure the output folders exist
os.makedirs(output_folder, exist_ok=True)
tumor_types = {1: "meningioma", 2: "glioma", 3: "pituitary"}
for folder in tumor_types.values():
    os.makedirs(os.path.join(output_folder, folder), exist_ok=True)

# Resize size
IMG_SIZE = 224

# Process each .mat file
files = [f for f in os.listdir(mat_dir) if f.endswith('.mat')]

for idx, file_name in enumerate(tqdm(files)):
    try:
        file_path = os.path.join(mat_dir, file_name)
        with h5py.File(file_path, 'r') as f:
            cjdata = f['cjdata']
            image = np.array(cjdata['image'])
            label = int(np.array(cjdata['label'])[0][0])

            if label not in tumor_types:
                continue  # Skip unknown labels

            # Resize and normalize image
            image_resized = cv2.resize(image, (IMG_SIZE, IMG_SIZE))
            image_resized = np.uint8(image_resized / np.max(image_resized) * 255)

            # Output path
            save_path = os.path.join(output_folder, tumor_types[label], f"{idx}.jpg")

            # Save the image
            cv2.imwrite(save_path, image_resized)

    except Exception as e:
        print(f"❌ Error in file {file_name}: {e}")

print("✅ All images converted and saved!")

# 📦 ZIP the entire folder into Kaggle-style format
zip_filename = "kaggle_format.zip"
with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
    for root, _, files in os.walk(output_folder):
        for file in files:
            full_path = os.path.join(root, file)
            arcname = os.path.relpath(full_path, output_folder)
            zipf.write(full_path, arcname)

print(f"✅ Zipping complete! Output saved as: {zip_filename}")
# Out:
# 100%|██████████| 766/766 [00:18<00:00, 41.90it/s]
# ✅ All images converted and saved!
# ✅ Zipping complete! Output saved as: kaggle_format.zip

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

IMG_SIZE = 224
EPOCHS = 10
NUM_CLASSES = 3

# Build CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(NUM_CLASSES, activation='softmax')
])

# Compile the model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Summary of model
model.summary()
# Out:
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224
BATCH_SIZE = 32

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    'converted_dataset',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    'converted_dataset',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation'
)
# Out:
# Found 1676 images belonging to 3 classes.
# Found 418 images belonging to 3 classes.

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS
)
# Out:
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 53s 960ms/step - accuracy: 0.4604 - loss: 1.0941 - val_accuracy: 0.7775 - val_loss: 0.5774
# Epoch 2/10
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 28s 537ms/step - accuracy: 0.7454 - loss: 0.5783 - val_accuracy: 0.7632 - val_loss: 0.5265
# Epoch 3/10
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 540ms/step - accuracy: 0.8443 - loss: 0.3837 - val_accuracy: 0.8182 - val_loss: 0.5120
# Epoch 4/10
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 29s 541ms/step - accuracy: 0.8940 - loss: 0.2517 - val_accuracy: 0.8421 - val_loss: 0.5144
# Epoch 5/10
# ...

# %%
import matplotlib.pyplot as plt

# Accuracy plot
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# Loss plot
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Save the trained model
model.save("tumor_type_classifier.h5")

print("✅ Model has been saved as 'tumor_type_classifier.h5'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model has been saved as 'tumor_type_classifier.h5'

# %%
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# Load your saved model
model = load_model("tumor_type_classifier.h5")

# Define class labels (should match your folder order in 'converted_dataset')
class_labels = ['glioma', 'meningioma', 'pituitary']

# Preprocessing function
def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (224, 224))        # Match training input size
    img = img / 255.0                         # Normalize pixel values
    img = img.reshape(1, 224, 224, 1)         # Add batch + channel dimensions
    return img

# Path to your test image
test_image_path = r"C:\Users\m6793\OneDrive\Pictures\Documents\Desktop\test_images\Y6.jpg"
  # 👈 Change this path to your test image

# Predict
img = preprocess_image(test_image_path)
pred = model.predict(img)

# Get prediction label
predicted_class = class_labels[np.argmax(pred)]
confidence = np.max(pred)

print(f"✅ Predicted Tumor Type: {predicted_class} ({confidence:.2f} confidence)")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# ✅ Predicted Tumor Type: glioma (1.00 confidence)

# %%
img = preprocess_image(test_image_path)
pred = model.predict(img)

predicted_class = class_labels[np.argmax(pred)]
confidence = np.max(pred)

print(f"✅ Predicted Tumor Type: {predicted_class} ({confidence:.2f} confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ Predicted Tumor Type: glioma (1.00 confidence)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224
BATCH_SIZE = 32

# Prepare binary classification data loader
datagen_binary = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_gen_bin = datagen_binary.flow_from_directory(
    r'C:\Users\m6793\Downloads\archive',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',  # 🧠 Binary classification
    color_mode='grayscale',
    subset='training'
)

val_gen_bin = datagen_binary.flow_from_directory(
    r'C:\Users\m6793\Downloads\archive',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    color_mode='grayscale',
    subset='validation'
)

print("✅ Class Indices:", train_gen_bin.class_indices)
# Out:
# Found 406 images belonging to 3 classes.
# Found 100 images belonging to 3 classes.
# ✅ Class Indices: {'brain_tumor_dataset': 0, 'no': 1, 'yes': 2}

# %%
# for kaggle dataset building a model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Define the model
model_bin = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224, 224, 1)),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # 👉 Binary output (0 or 1)
])

# Compile the model
model_bin.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Show model summary
model_bin.summary()
# Out:
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
EPOCHS = 10

history_bin = model_bin.fit(
    train_gen_bin,
    validation_data=val_gen_bin,
    epochs=EPOCHS
)
# Out:
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 716ms/step - accuracy: 0.2626 - loss: 0.6815 - val_accuracy: 0.1900 - val_loss: 0.3805
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 405ms/step - accuracy: 0.1656 - loss: 0.5526 - val_accuracy: 0.1900 - val_loss: 0.3276
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 434ms/step - accuracy: 0.1985 - loss: 0.4149 - val_accuracy: 0.1900 - val_loss: 0.4485
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 520ms/step - accuracy: 0.2191 - loss: 0.5724 - val_accuracy: 0.1900 - val_loss: 0.4120
# Epoch 5/10
# ...

# %%
model_bin.save("tumor_presence_detector.h5")
print("✅ Binary model saved as tumor_presence_detector.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Binary model saved as tumor_presence_detector.h5

# %%
history_bin = model_bin.fit(
    train_gen_bin,
    validation_data=val_gen_bin,
    epochs=10
)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 415ms/step - accuracy: 0.2081 - loss: 0.4383 - val_accuracy: 0.1900 - val_loss: 0.5249
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - accuracy: 0.1812 - loss: 0.4601 - val_accuracy: 0.1900 - val_loss: 0.4779
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 488ms/step - accuracy: 0.2024 - loss: 0.4459 - val_accuracy: 0.1900 - val_loss: 0.5264
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 523ms/step - accuracy: 0.2195 - loss: 0.4993 - val_accuracy: 0.1900 - val_loss: 0.4614
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 569ms/step - accuracy: 0.1716 - loss: 0.3054 - val_accuracy: 0.2000 - val_loss: 0.5812
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 567ms/step - accuracy: 0.1943 - loss: 0.4904 - val_accuracy: 0.1900 - val_loss: 0.5546
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 7s 532ms/step - accuracy: 0.2091 - loss: 0.4854 - val_accuracy: 0.1900 - val_loss: 0.5801
# Epoch 8/10
# ...

# %%
import matplotlib.pyplot as plt

# ✅ Plot Accuracy
plt.figure(figsize=(8, 5))
plt.plot(history_bin.history['accuracy'], label='Train Accuracy')
plt.plot(history_bin.history['val_accuracy'], label='Validation Accuracy')
plt.title("Model Accuracy (Tumor vs No Tumor)")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()

# ✅ Plot Loss
plt.figure(figsize=(8, 5))
plt.plot(history_bin.history['loss'], label='Train Loss')
plt.plot(history_bin.history['val_loss'], label='Validation Loss')
plt.title("Model Loss (Tumor vs No Tumor)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# ✅ Load the saved Stage 1 binary model
model_bin = load_model("tumor_presence_detector.h5")
print("✅ Model loaded successfully.")

# ✅ Define preprocessing function
def preprocess_binary_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Load in grayscale
    if img is None:
        raise ValueError("❌ Image not found or path is incorrect.")
    
    img = cv2.resize(img, (224, 224))      # Resize to match model input
    img = img / 255.0                      # Normalize
    img = img.reshape(1, 224, 224, 1)      # Add batch & channel dimensions
    return img

# ✅ Path to test image (change this!)
test_image_path = r"C:\Users\m6793\Downloads\archive\no\8 no.jpg"

# ✅ Preprocess and predict
try:
    img = preprocess_binary_image(test_image_path)
    prediction = model_bin.predict(img)[0][0]  # Raw probability

    # ✅ Threshold-based decision
    result = "Tumor" if prediction >= 0.5 else "No Tumor"
    print(f"🧠 Prediction: {result} ({prediction:.2f} confidence)")

except Exception as e:
    print("❌ Error:", str(e))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model loaded successfully.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 🧠 Prediction: Tumor (0.72 confidence)

# %%
import numpy as np
import cv2
from tensorflow.keras.models import load_model

# ✅ Load Stage 2 model
model_stage2 = load_model("tumor_type_classifier.h5")
print("✅ Stage 2 model loaded.")

# ✅ Class labels (MUST match folder order used during training)
class_labels = ['glioma', 'meningioma', 'pituitary']

# ✅ Preprocessing function
def preprocess_stage2_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError("❌ Image not found or invalid path.")
    
    img = cv2.resize(img, (224, 224))
    img = img / 255.0
    img = img.reshape(1, 224, 224, 1)
    return img

# ✅ Path to test image (change this!)
test_image_path = r"C:\Users\m6793\Downloads\archive\no\No22.jpg" 


# ✅ Preprocess and predict
try:
    img = preprocess_stage2_image(test_image_path)
    pred = model_stage2.predict(img)
    predicted_class = class_labels[np.argmax(pred)]
    confidence = np.max(pred)

    print(f"🧠 Tumor Type: {predicted_class} ({confidence:.2f} confidence)")

except Exception as e:
    print("❌ Error:", str(e))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Stage 2 model loaded.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F14A395D80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
import os

tumor_dir = r'C:\Users\m6793\Downloads\archive\yes'
no_tumor_dir = r'C:\Users\m6793\Downloads\archive\no'

tumor_count = len(os.listdir(tumor_dir))
no_tumor_count = len(os.listdir(no_tumor_dir))

print(f"Tumor Images: {tumor_count}")
print(f"No Tumor Images: {no_tumor_count}")
# Out:
# Tumor Images: 155
# No Tumor Images: 98

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen_binary = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

train_gen_bin = datagen_binary.flow_from_directory(
    r'C:\Users\m6793\Downloads\archive',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    color_mode='grayscale',
    subset='training'
)

val_gen_bin = datagen_binary.flow_from_directory(
    r'C:\Users\m6793\Downloads\archive',
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary',
    color_mode='grayscale',
    subset='validation'
)
# Out:
# Found 406 images belonging to 3 classes.
# Found 100 images belonging to 3 classes.

# %%
import os
import cv2
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tqdm import tqdm

# 🔁 Path to your 'no_tumor' folder
input_folder = r'C:\Users\m6793\Downloads\archive\no'
output_folder = input_folder  # Saving into the same folder

# ✅ Set up the augmentation generator
datagen = ImageDataGenerator(
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# 🔢 How many augmented images per original?
AUG_PER_IMAGE = 2  # You can change to 3, 4 etc. to match the tumor count

# 📁 Get list of images
image_files = [f for f in os.listdir(input_folder) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

print(f"Found {len(image_files)} images. Generating {AUG_PER_IMAGE} per image...")

for img_file in tqdm(image_files):
    img_path = os.path.join(input_folder, img_file)
    img = cv2.imread(img_path)
    if img is None:
        continue
    img = cv2.resize(img, (224, 224))  # Resize to model input shape
    img = np.expand_dims(img, axis=0)

    # Generate and save augmented images
    gen = datagen.flow(img, batch_size=1)
    for i in range(AUG_PER_IMAGE):
        aug_img = next(gen)[0].astype(np.uint8)
        save_path = os.path.join(output_folder, f"aug_{i}_{img_file}")
        cv2.imwrite(save_path, aug_img)

print("✅ Augmentation complete!")
# Out:
# Found 98 images. Generating 2 per image...
# 100%|██████████| 98/98 [00:03<00:00, 31.76it/s]
# ✅ Augmentation complete!

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# 🔧 Settings
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 15

# ✅ Image generators (with augmentation for training)
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    zoom_range=0.15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    r'C:\Users\m6793\Downloads\archive',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    color_mode='grayscale',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    r'C:\Users\m6793\Downloads\archive',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    color_mode='grayscale',
    subset='validation'
)

# ✅ CNN model
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)),
    MaxPooling2D(2,2),
    
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')  # Binary classification
])

model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# ✅ Train the model
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=EPOCHS
)

# ✅ Save the trained model
model.save("tumor_presence_detector.h5")
print("✅ Model saved as 'tumor_presence_detector.h5'")

# 📊 Plot accuracy/loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Loss')
plt.legend()
plt.show()
# Out:
# Found 563 images belonging to 3 classes.
# Found 139 images belonging to 3 classes.
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/15
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 13s 620ms/step - accuracy: 0.4387 - loss: 0.5588 - val_accuracy: 0.4173 - val_loss: 0.2623
# Epoch 2/15
# ...

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load trained Stage 1 model
model = load_model("tumor_presence_detector.h5")

# Function to preprocess input image
def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Image not found or unreadable: {img_path}")
    img = cv2.resize(img, (224, 224))
    img = img / 255.0  # normalize
    img = img.reshape(1, 224, 224, 1)  # reshape for model input
    return img

# === TEST 1: No Tumor Image ===
no_tumor_path = r"C:\Users\m6793\Downloads\archive\no\30 no.jpg"  # Replace with a real image path
img1 = preprocess_image(no_tumor_path)
pred1 = model.predict(img1)[0][0]

print("🔍 Test 1 - No Tumor Image:")
if pred1 > 0.5:
    print(f"🧠 Tumor Detected (confidence: {pred1:.2f}) ❌")
else:
    print(f"✅ No Tumor Detected (confidence: {1 - pred1:.2f})")

print("\n" + "-"*50 + "\n")

# === TEST 2: Tumor Image ===
tumor_path = r"C:\Users\m6793\Downloads\archive\tumor\example2.jpg"  # Replace with a real image path
img2 = preprocess_image(tumor_path)
pred2 = model.predict(img2)[0][0]

print("🔍 Test 2 - Tumor Image:")
if pred2 > 0.5:
    print(f"🧠 Tumor Detected (confidence: {pred2:.2f}) ✅")
else:
    print(f"❌ No Tumor Detected (confidence: {1 - pred2:.2f})")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001F14BE38310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
import cv2
import os

test_image_path = r"c:\Users\m6793\Downloads\image_01(1).jpg"

print("🛠️ Path exists?", os.path.exists(test_image_path))
img = cv2.imread(test_image_path, cv2.IMREAD_GRAYSCALE)

if img is None:
    print("❌ OpenCV could not load the image.")
else:
    print("✅ Image loaded successfully.")
# Out:
# 🛠️ Path exists? True
# ✅ Image loaded successfully.

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load trained Stage 1 model
model = load_model("tumor_presence_detector.h5")

# Function to preprocess input image
def preprocess_image(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        raise ValueError(f"Image not found or unreadable: {img_path}")
    img = cv2.resize(img, (224, 224))
    img = img / 255.0  # normalize
    img = img.reshape(1, 224, 224, 1)  # reshape for model input
    return img

# === TEST 1: No Tumor Image ===
no_tumor_path = r"c:\Users\m6793\Downloads\image_01(1).jpg"  # Replace with a real image path
img1 = preprocess_image(no_tumor_path)
pred1 = model.predict(img1)[0][0]

print("🔍 Test 1 - No Tumor Image:")
if pred1 > 0.5:
    print(f"🧠 Tumor Detected (confidence: {pred1:.2f}) ❌")
else:
    print(f"✅ No Tumor Detected (confidence: {1 - pred1:.2f})")

print("\n" + "-"*50 + "\n")

# === TEST 2: Tumor Image ===
tumor_path = r"C:\Users\m6793\Downloads\archive\tumor\example2.jpg"  # Replace with a real image path
img2 = preprocess_image(tumor_path)
pred2 = model.predict(img2)[0][0]

print("🔍 Test 2 - Tumor Image:")
if pred2 > 0.5:
    print(f"🧠 Tumor Detected (confidence: {pred2:.2f}) ✅")
else:
    print(f"❌ No Tumor Detected (confidence: {1 - pred2:.2f})")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 🔍 Test 1 - No Tumor Image:
# 🧠 Tumor Detected (confidence: 0.82) ❌
#
# --------------------------------------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 33
#      31 # === TEST 2: Tumor Image ===
#      32 tumor_path = r"C:\Users\m6793\Downloads\archive\tumor\example2.jpg"  # Replace with a real image path
# ---> 33 img2 = preprocess_image(tumor_path)
#      34 pred2 = model.predict(img2)[0][0]
#      36 print("🔍 Test 2 - Tumor Image:")
#
# Cell In[17], line 12, in preprocess_image(img_path)
#      10 img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
#      11 if img is None:
# ...

# %%
import os
import shutil
from glob import glob

# Paths to your existing data
kaggle_tumor_dir = r'C:\Users\m6793\Downloads\archive\yes'
kaggle_no_tumor_dir = r'C:\Users\m6793\Downloads\archive\no'

# Target folder
target_base = r'C:\Users\m6793\Downloads\stage1_dataset'
tumor_target = os.path.join(target_base, 'tumor')
no_tumor_target = os.path.join(target_base, 'no_tumor')

# Create folders
os.makedirs(tumor_target, exist_ok=True)
os.makedirs(no_tumor_target, exist_ok=True)

# Copy tumor images
for file in glob(os.path.join(kaggle_tumor_dir, '*.jpg')):
    shutil.copy(file, tumor_target)

# Copy no_tumor images
for file in glob(os.path.join(kaggle_no_tumor_dir, '*.jpg')):
    shutil.copy(file, no_tumor_target)

print("✅ Stage 1 dataset is ready at:", target_base)
# Out:
# ✅ Stage 1 dataset is ready at: C:\Users\m6793\Downloads\stage1_dataset

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# Constants
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 10
DATASET_PATH = r'C:\Users\m6793\Downloads\stage1_dataset'  # ✅ Update if needed

# Data Augmentation and Loader
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_gen = train_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    color_mode='rgb',
    subset='training'
)

val_gen = train_datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    color_mode='rgb',
    subset='validation'
)

# ✅ Build Model using MobileNetV2
base_model = MobileNetV2(include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3), weights='imagenet')
base_model.trainable = False  # Freeze base

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(1, activation='sigmoid')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)

# Save
model.save("tumor_presence_mobilenet.h5")
print("✅ Model saved as tumor_presence_mobilenet.h5")
# Out:
# Found 343 images belonging to 2 classes.
# Found 84 images belonging to 2 classes.
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step - accuracy: 0.4942 - loss: 0.8438 - val_accuracy: 0.6429 - val_loss: 0.6352
# Epoch 2/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 6s 588ms/step - accuracy: 0.6829 - loss: 0.6637 - val_accuracy: 0.7738 - val_loss: 0.5279
# Epoch 3/10
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 7s 630ms/step - accuracy: 0.7406 - loss: 0.4928 - val_accuracy: 0.8452 - val_loss: 0.4542
# Epoch 4/10
# ...

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label="Train Accuracy")
plt.plot(history.history['val_accuracy'], label="Val Accuracy")
plt.legend()
plt.title("Accuracy")

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label="Train Loss")
plt.plot(history.history['val_loss'], label="Val Loss")
plt.legend()
plt.title("Loss")

plt.show()

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# Load trained model
model = load_model("tumor_presence_mobilenet.h5")

# Prediction function
def preprocess_image(img_path):
    img = cv2.imread(img_path)
    if img is None:
        raise ValueError("❌ Image not found at provided path!")
    
    img = cv2.resize(img, (224, 224))
    img = img / 255.0
    img = img.reshape(1, 224, 224, 3)  # RGB shape
    return img

# 🔍 Set your test image path here
test_image_path = r"c:\Users\m6793\Downloads\image_01(1).jpg"

# Run prediction
img = preprocess_image(test_image_path)
prediction = model.predict(img)[0][0]

# Result
if prediction < 0.5:
    print(f"✅ No Tumor Detected (confidence: {1 - prediction:.2f})")
else:
    print(f"🧠 Tumor Detected (confidence: {prediction:.2f})")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 789ms/step
# ✅ No Tumor Detected (confidence: 0.91)

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
import matplotlib.pyplot as plt

# Settings
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 10
DATASET_PATH = r'C:\Users\m6793\OneDrive\Pictures\Documents\bt_using_dl\kaggle_format'

# Data generator
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    zoom_range=0.1,
    horizontal_flip=True
)

train_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',
    subset='training'
)

val_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    color_mode='rgb',
    subset='validation'
)

# Build model
base_model = MobileNetV2(include_top=False, input_shape=(IMG_SIZE, IMG_SIZE, 3), weights='imagenet')
base_model.trainable = False  # Freeze base

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
predictions = Dense(3, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(train_gen, validation_data=val_gen, epochs=EPOCHS)

# Save
model.save("tumor_type_mobilenet.h5")
print("✅ Stage 2 model saved as tumor_type_mobilenet.h5")
# Out:
# Found 1676 images belonging to 3 classes.
# Found 418 images belonging to 3 classes.
# c:\ProgramData\anaconda3\envs\tf-env\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 54s 963ms/step - accuracy: 0.4744 - loss: 1.1490 - val_accuracy: 0.8325 - val_loss: 0.5478
# Epoch 2/10
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 33s 615ms/step - accuracy: 0.8029 - loss: 0.5104 - val_accuracy: 0.8541 - val_loss: 0.4093
# Epoch 3/10
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 42s 798ms/step - accuracy: 0.8732 - loss: 0.3684 - val_accuracy: 0.8804 - val_loss: 0.3767
# Epoch 4/10
# ...

# %%
pip install gradio
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/59.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/59.6 MB ? eta -:--:--
#     --------------------------------------- 0.8/59.6 MB 1.8 MB/s eta 0:00:34
#     --------------------------------------- 1.0/59.6 MB 1.9 MB/s eta 0:00:32
#    - -------------------------------------- 1.6/59.6 MB 1.9 MB/s eta 0:00:32
#    - -------------------------------------- 1.8/59.6 MB 1.9 MB/s eta 0:00:31
#    - -------------------------------------- 2.4/59.6 MB 1.9 MB/s eta 0:00:30
#    - -------------------------------------- 2.9/59.6 MB 2.0 MB/s eta 0:00:29
#    -- ------------------------------------- 3.4/59.6 MB 2.1 MB/s eta 0:00:28
#    -- ------------------------------------- 3.7/59.6 MB 2.0 MB/s eta 0:00:28
#    -- ------------------------------------- 4.2/59.6 MB 2.1 MB/s eta 0:00:27
# ...

# %%
# Save Stage 1 model
model_bin.save("tumor_presence_mobilenet.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Save Stage 1 model
# ----> 2 model_bin.save("tumor_presence_mobilenet.h5")
#
# NameError: name 'model_bin' is not defined
